# %% [markdown]
# # CGM Patient Voice Intelligence
#
# This notebook is the technical narrative behind the Strategy Intelligence Dashboard. It uses the public synthetic sample by default; the dashboard can also run against the local private CGM Excel export through `STRATEGY_DASHBOARD_RAW_XLSX` without copying raw data into the repo.

# %%
from pathlib import Path
import json
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from strategy_dashboard.data import load_case_data, load_config
from strategy_dashboard.pipeline import run_case_analysis

config = load_config(ROOT / 'configs' / 'cgm_healthcare.json')
frame = load_case_data(ROOT / 'data' / 'sample' / 'synthetic_cgm_posts.csv')
frame.head()

# %% [markdown]
# ## Run the consulting intelligence pipeline
#
# The same package code powers the Streamlit dashboard and the tests: schema validation, text cleaning, brand tagging, taxonomy labeling, NMF topics, KMeans segments, opportunity scoring, and executive brief synthesis.

# %%
analysis = run_case_analysis(frame, config, include_models=True)
analysis.keys()

# %%
analysis['benchmark']

# %%
analysis['scores'].head(10)

# %%
analysis['segments']

# %%
analysis['brief']

# %% [markdown]
# ## Interpretation
#
# The public sample is intentionally small and synthetic. The full local CGM case uses 37,844 posts and should be treated as directional market-intelligence evidence rather than clinical truth. The dashboard is designed to make strategy tradeoffs explicit: decision-makers can reweight market size, sentiment risk, urgency, and brand gap to see how priorities move.
